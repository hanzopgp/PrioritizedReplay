# %% [markdown]
# ## Imports

# %%
# %load_ext autoreload
# %autoreload 2
import pickle
import os
import glob
import matplotlib.pyplot as plt
from datetime import datetime
import numpy as np
from parameters import setParams
from main import Replay_Sim
from analysis_class import Sim_Data## Define models to analyse

# %% [markdown]
# ## Run n simulations for each model (check parameters.py)
# (EVB, gain-only, need-only, dyna, no_replay, prioritized_sweeping)

# %%
import run
# Out:
# Starting simulations for the mattar maze
#
# Using mattar maze. Starting position in yellow, walls in light blue, pre transition reward in dark blue
# After reward function change, reward in dark blue
# Simulation number:  0
#
# Starting a new simulation (exploring the environment); strategy: prioritized_sweeping
# 393 steps; 24 episodes
# Goal location changed
# 1090 steps; 49 episodes
# Done with prioritized_sweeping simulation #1 out of #2
# Simulation number:  1
#
# Starting a new simulation (exploring the environment); strategy: prioritized_sweeping
# 427 steps; 24 episodes
# Goal location changed
# 1039 steps; 49 episodes
# Done with prioritized_sweeping simulation #2 out of #2
# Simulation number:  0
#
# Starting a new simulation (exploring the environment); strategy: dyna
# 1798 steps; 24 episodes
# Goal location changed
# 10047 steps; 49 episodes
# Done with dyna simulation #1 out of #2
# Simulation number:  1
#
# Starting a new simulation (exploring the environment); strategy: dyna
# 3658 steps; 24 episodes
# Goal location changed
# 6767 steps; 49 episodes
# Done with dyna simulation #2 out of #2
# Simulation number:  0
#
# Starting a new simulation (exploring the environment); strategy: no_replay
# 5193 steps; 24 episodes
# Goal location changed
# 19607 steps; 49 episodes
# Done with no_replay simulation #1 out of #2
# Simulation number:  1
#
# Starting a new simulation (exploring the environment); strategy: no_replay
# 2817 steps; 24 episodes
# Goal location changed
# 28355 steps; 49 episodes
# Done with no_replay simulation #2 out of #2
# Simulation number:  0
#
# Starting a new simulation (exploring the environment); strategy: need_only
# 1622 steps; 24 episodes
# Goal location changed
# 9685 steps; 49 episodes
# Done with need_only simulation #1 out of #2
# Simulation number:  1
#
# Starting a new simulation (exploring the environment); strategy: need_only
# 2157 steps; 24 episodes
# Goal location changed
# 13429 steps; 49 episodes
# Done with need_only simulation #2 out of #2
# Simulation number:  0
#
# Starting a new simulation (exploring the environment); strategy: gain_only
# 291 steps; 24 episodes
# Goal location changed
# 1089 steps; 49 episodes
# Done with gain_only simulation #1 out of #2
# Simulation number:  1
#
# Starting a new simulation (exploring the environment); strategy: gain_only
# 1429 steps; 24 episodes
# Goal location changed
# 3085 steps; 49 episodes
# Done with gain_only simulation #2 out of #2
# Simulation number:  0
#
# Starting a new simulation (exploring the environment); strategy: EVB
# 536 steps; 24 episodes
# Goal location changed
# 2956 steps; 49 episodes
# Done with EVB simulation #1 out of #2
# Simulation number:  1
#
# Starting a new simulation (exploring the environment); strategy: EVB
# 2541 steps; 24 episodes
# Goal location changed
# 4476 steps; 49 episodes
# Done with EVB simulation #2 out of #2

# %% [markdown]
# ## Define models to analyse

# %%
## Extract data for each maze different replay strategies (models)
models = ['EVB', 'gain_only', 'need_only', 'dyna', 'no_replay', 'prioritized_sweeping']

# %% [markdown]
# ## Extract data for each maze

# %%
# the name of the maze depends on how parameters.py was set when calling run.py
Mattar_Open = Sim_Data('mattar', models)

#Mattar = Sim_Data('mattar', models)
#Tmaze = Sim_Data('t_maze', models)
#Mattar_Constrained = Sim_Data('mattar_constrained', models)
#Large_Open = Sim_Data('large_open', models)

maze_data_list = [Mattar_Open]
# maze_data_list = [Mattar, Mattar_Open, Mattar_Constrained, Large_Open]

# %% [markdown]
# ## Function to plot all mazes

# %%
def plot_mazes(maze_data_list, dependent_var, y_label, title, plot_logs, crop_y):
    log_vals_bools = [False]
    if plot_logs:
        log_vals_bools.append(True)
    for bool_val in log_vals_bools:
        for maze in maze_data_list:
            maze.plot_fig(dependent_var, y_label=y_label, title=title, log_values=bool_val, crop_y=crop_y)

# %% [markdown]
# ## Steps per episode

# %%
dependent_var = 'steps_per_episode'
y_label = 'Steps'
title = 'Total steps per Episode'
plot_log = True
crop_y = False
plot_mazes(maze_data_list, dependent_var, y_label, title, plot_log, crop_y)

# %% [markdown]
# ## Total time per episode (absolute values are dependent on the computer performances)

# %%
## Steps per episode

# %% [markdown]
# ## Planning time per episode

# %%
dependent_var = 'plan_times'
y_label = 'Time'
title = 'Plan Time per Episode'
plot_log = True
crop_y = False
plot_mazes(maze_data_list, dependent_var, y_label, title, plot_log, crop_y)

# %% [markdown]
# ## EVB time per episode

# %%
dependent_var = 'EVB_times'
y_label = 'Time'
title = 'EVB Time per Episode'
plot_log = True
crop_y = False
plot_mazes(maze_data_list, dependent_var, y_label, title, plot_log, crop_y)

# %% [markdown]
# ## Gain time per episode

# %%
dependent_var = 'gain_times'
y_label = 'Time'
title = 'Gain Time per Episode'
plot_log = True
crop_y = False
plot_mazes(maze_data_list, dependent_var, y_label, title, plot_log, crop_y)

# %% [markdown]
# ## Need time per episode

# %%
dependent_var = 'need_times'
y_label = 'Time'
title = 'Need Time per Episode'
plot_log = True
crop_y = False
plot_mazes(maze_data_list, dependent_var, y_label, title, plot_log, crop_y)
